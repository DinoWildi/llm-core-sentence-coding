# %% [markdown]
# # Local notebook: test
#
# This serves as a development tool to locally test the ability to call and use LLM models via ollama. The code from this notebook is not intended for use in the eventual paper.
#
# ### Setup
#
# This section does the following
# * loading packages
# * downloading intended models
# * loading and preparing data

# %%
import pandas as pd
import numpy as np
import ollama

from src.io import read_tabular
from pathlib import Path
from tqdm.notebook import tqdm

# %%
MISTRAL = 'mistral-small3.2:24b'
GPT_OSS = 'gpt-oss:20b'
GEMMA = 'gemma3:4b'

ollama.pull(MISTRAL)
ollama.pull(GPT_OSS)
ollama.pull(GEMMA)
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
fp = Path("data")
df = read_tabular(fp / 'sz_test.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 fp = Path("data")
# ----> 2 df = read_tabular(fp / 'sz_test.csv')
#
# File c:\Users\dino1\Documents\GitHub\llm-core-sentence-coding\dev_local\src\io.py:23, in read_tabular(path, columns, **kwargs)
#      21 def read_tabular(path: str, columns: Optional[List[str]]=None, **kwargs) -> 'pd.DataFrame':
#      22     if not _is_file(str(path)):
# ---> 23         raise FileNotFoundError(f'File not found: {path}')
#      25     sep = _get_col_separator(str(path))
#      26     if sep is None:
#
# FileNotFoundError: File not found: data\sz_test.csv
